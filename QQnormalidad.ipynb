# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
presion_antes = np.array([126, 114, 110, 108, 131, 109, 121, 123, 127, 128, 125, 131, 128, 129,
                    134, 116, 105, 118, 124, 121, 127, 142, 138, 139, 110, 112, 114, 121,
                    131, 125, 128, 129, 130, 137, 125, 124, 123, 122, 120, 112, 126, 125,
                    151, 141, 118, 132, 136, 129, 140, 125, 138, 129, 107, 117, 96, 110,
                    121, 145, 139, 121, 127, 153, 125, 130, 108, 105, 112, 121, 102, 120,
                    115, 143, 138, 135, 140, 143, 119, 121, 143, 138, 100, 118, 121, 126,
                    135, 134, 149, 121, 125, 136, 140, 142, 135, 108, 115, 117, 148, 121,
                    154, 120])

# %%
stats.probplot(presion_antes, dist="norm", plot=plt)

plt.title("Gráfico QQ prueba Normalidad para Presión sistólica Antes")
plt.show()

# %%
presion_despues = np.array([118, 110, 110, 105, 132, 110, 115, 110, 122, 120,
                            125, 128, 134, 132, 131, 115, 106, 110, 118, 117,
                            127, 138, 129, 125, 110, 108, 103, 115, 142, 124,
                            121, 123, 121, 131, 121, 120, 119, 115, 120, 116,
                            124, 120, 158, 135, 130, 128, 141, 123, 113, 124,
                            139, 118, 120, 118, 96, 105, 110, 155, 135, 120,
                            115, 161, 120, 120, 102, 83, 105, 90, 101, 115,
                            115, 152, 125, 138, 138, 135, 120, 118, 140, 134,
                            77, 121, 120, 121, 130, 133, 145, 122, 120, 134,
                            135, 138, 130, 105, 110, 100, 141, 115, 155, 116])

# %%
stats.probplot(presion_despues, dist="norm", plot=plt)

plt.title("Gráfico QQ prueba Normalidad para Presión sistólica Después")
plt.show()

# %%
stats.shapiro(presion_antes)
# Out:
# ShapiroResult(statistic=np.float64(0.9919231354802636), pvalue=np.float64(0.8156294109699813))

# %%
stats.shapiro(presion_despues)
# Out:
# ShapiroResult(statistic=np.float64(0.9788826299968818), pvalue=np.float64(0.10874561600201343))
